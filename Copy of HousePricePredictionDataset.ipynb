# %%
import pandas as pd

# %%
df= pd.read_csv("/content/House Price Prediction Dataset.csv")

# %%
df.head()
# Out:
#    Id    Area Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360.0        5          4       3       1970  Downtown  Excellent
# 1   2  4272.0        5          4       3       1958  Downtown  Excellent
# 2   3  3592.0        2          2       3       1938  Downtown       Good
# 3   4   966.0        4          2       2       1902  Suburban       Fair
# 4   5  4926.0        1          4       2       1975  Downtown       Fair
#
#   Garage     Price
# 0     No  149919.0
# 1     No  424998.0
# 2     No  266746.0
# 3    Yes  244020.0
# 4    Yes  636056.0

# %%
df.isnull().sum()
# Out:
# Id            0
# Area         13
# Bedrooms     18
# Bathrooms     0
# Floors        0
# YearBuilt     0
# Location     15
# Condition     0
# Garage       16
# Price        17
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/House Price Prediction Dataset.csv")

# Calculate missing values
missing_values = df.isnull().sum()

# Plot only columns with missing values
missing_values[missing_values > 0].plot(kind='bar')

# Chart labels
plt.title("Missing Data Pattern")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")

plt.show()

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/House Price Prediction Dataset.csv")

# Select numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Apply median imputation correctly
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
df[num_cols].isnull().sum()
# Out:
# Id           0
# Area         0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Price        0
# dtype: int64

# %%
df[cat_cols] = df[cat_cols].apply(lambda x: x.fillna(x.mode()[0]))

# %%
import pandas as pd

df = pd.read_csv("/content/House Price Prediction Dataset.csv")

cat_cols = df.select_dtypes(include=['object']).columns

df[cat_cols] = df[cat_cols].apply(lambda x: x.fillna(x.mode()[0]))

# %%
df.head()
df.iloc[:10, :10]
# Out:
#    Id    Area Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360.0        5          4       3       1970  Downtown  Excellent
# 1   2  4272.0        5          4       3       1958  Downtown  Excellent
# 2   3  3592.0        2          2       3       1938  Downtown       Good
# 3   4   966.0        4          2       2       1902  Suburban       Fair
# 4   5  4926.0        1          4       2       1975  Downtown       Fair
# 5   6  3944.0        1          2       1       1906     Urban       Poor
# 6   7  3671.0        1          1       2       1948     Rural       Poor
# 7   8  3419.0        2          4       1       1925  Suburban       Good
# 8   9     NaN        2          2       1       1932  Downtown       Poor
# 9  10  2185.0        3          3       1       2000  Downtown       Poor
#
#   Garage     Price
# 0     No  149919.0
# 1     No  424998.0
# 2     No  266746.0
# 3    Yes  244020.0
# 4    Yes  636056.0
# 5     No       NaN
# 6    Yes  448722.0
# 7     No  594893.0
# 8    Yes  652878.0
# 9     No  340375.0
